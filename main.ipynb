# %% [markdown]
# - 코드를 동작하는데 필요한 외부 라이브러리를 다운로드합니다.

# %%
# %pip install --quiet -r requirements.txt

# %% [markdown]
# - 선택 이후에 회로도가 어떻게 변하는지를 시각화

# %%
# %run main.py

# %% [markdown]
# - 각 상황에서 합성저항을 구하기

# %%
# %run resistance.py

# %% [markdown]
# - 답 구하기 & 시각화

# %%
# %run answer.py
